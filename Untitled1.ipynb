# %%
list=[1,2,3,4,5]
for i in range(len(list)):
    print(list[i])

name="Haider Nasir"
def func1(nam):
    return nam;

print("NAME IS",func1(name))
# Out:
# 1
# 2
# 3
# 4
# 5
# NAME IS Haider Nasir
