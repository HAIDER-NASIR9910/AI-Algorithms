# %%
from collections import deque
import heapq
def unifrom_cost_searchh(graph,start,goal):
  pq = [(0, [start])]
  visited=set()
  while pq:
    cost,path=heapq.heappop(pq)
    node=path[-1]
    if node==goal:
      return cost,path
    if node not in visited:
      visited.add(node)
      for cost_edge,neighbours in graph.get(node,[]):
        new_path=path+[neighbours]
        new_cost=cost+cost_edge
        heapq.heappush(pq,(new_cost,new_path))
  return  None
graph = {
    'A': [(1, 'B'), (4, 'C')],
    'B': [(2, 'D'), (5, 'E')],
    'C': [(3, 'F')],
    'D': [],
    'E': [(1, 'G')],
    'F': [],
    'G': []
}

print(unifrom_cost_searchh(graph, 'A', 'G'))
# Out:
# (7, ['A', 'B', 'E', 'G'])

# %%
def dls(graph,node,goal,deapth):
  visited=set()
  if node==goal:
    return [node]
  if deapth==0:
    return
  if node not in visited:
    visited.add(node)
    for neighbours in graph.get(node,[]):
      path=dls(graph,neighbours,goal,deapth-1)
      if path:
        return [node]+path
  return None

graph = {
    'A': ['B', 'C'],
    'B': ['D', 'E'],
    'C': ['F'],
    'D': [],
    'E': ['G'],
    'F': [],
    'G':[]
}
print(dls(graph,'A','G',3))
# Out:
# ['A', 'B', 'E', 'G']

# %%
from collections import deque
def bfs(graph,start,goal):
  visited=set()
  qeue=deque([[start]])
  while qeue:
    path=qeue.popleft()
    node=path[-1]
    if node==goal:
      return path
    if node not in visited:
      visited.add(node)
      for neighbour in graph.get(node,[]):
        new_path=path+[neighbour]
        qeue.append(new_path)
  return None
graph = {
    'A': ['B', 'C'],
    'B': ['D', 'E'],
    'C': ['F'],
    'D': [],
    'E': ['G'],
    'F': [],
    'G':[]
}
print(bfs(graph,'A','G'))
# Out:
# ['A', 'B', 'E', 'G']

# %%
def dfs(graph,start,goal):
  visited=set()
  stack=[start]
  while stack:
    node=stack.pop()
    if node not in visited:
      print(node)
      visited.add(node)
      stack.extend(reversed(graph[node]))
    if node==goal:
      return
graph = {
    'A': ['B', 'C'],
    'B': ['D', 'E'],
    'C': ['F'],
    'D': [],
    'E': ['G'],
    'F': [],
    'G':[]
}
print(dfs(graph,'A','G'))
# Out:
# A
# B
# D
# E
# G
# None

# %%
def dls(graph,node,goal,deapth):
  visited=set()
  if node==goal:
    return [node]
  if deapth==0:
    return
  if node not in visited:
    visited.add(node)
    for neighbour in graph.get(node,[]):
      path=dls(graph,neighbour,goal,deapth-1)
      if path:
        return [node]+path
  return None
def iddfs(graph,start,goal,max_deapth):
  for deapth in range(max_deapth):
    path=dls(graph,start,goal,deapth+1)
    if path:
      return path
  return None
graph = {
    'A': ['B', 'C'],
    'B': ['D', 'E'],
    'C': ['F'],
    'D': [],
    'E': ['G'],
    'F': [],
    'G': []
}

print(iddfs(graph, 'A', 'G', 5))
# Out:
# ['A', 'B', 'E', 'G']

# %%
def bidirectional_search(graph,start,goal):
  visited_s=set()
  visited_g=set()
  qeue_s=deque([start])
  qeue_g=deque([goal])

  path_s=qeue_s.popleft()
  node_s=path_s[-1]

  for neighbour_s in graph.get(node_s,[]):
      if neighbour_s in visited_g:    #unnion uses here to check and return
        return visited_g | visited_s
      new_path_s=path_s+[neighbour_s]
      qeue_s.append(new_path_s)

  path_g=qeue_g.popleft()
  node_g=path_g[-1]
  for neighbour_g in graph.get(node_g,[]):
      if neighbour_g in visited_s:     #uninon checks here and return the path
          return visited_s | visited_g
      new_path_g=path_g+[neighbour_g]
      qeue_g.append(new_path_g)

# %%
from collections import deque

def bidirectional_search(graph, start, goal):
    if start == goal:
        return [start]

    # Queues for forward and backward search
    queue_s = deque([[start]])
    queue_g = deque([[goal]])

    # Visited sets
    visited_s = {start}
    visited_g = {goal}

    while queue_s and queue_g:
        # --- Forward direction ---
        path_s = queue_s.popleft()
        node_s = path_s[-1]

        for neighbour in graph.get(node_s, []):
            if neighbour not in visited_s:
                new_path_s = path_s + [neighbour]
                queue_s.append(new_path_s)
                visited_s.add(neighbour)

                if neighbour in visited_g:
                    # Meeting point found
                    for path in queue_g:
                        if path[0] == neighbour:
                            return new_path_s[:-1] + path[::-1]

        # --- Backward direction ---
        path_g = queue_g.popleft()
        node_g = path_g[-1]

        for neighbour in graph.get(node_g, []):
            if neighbour not in visited_g:
                new_path_g = path_g + [neighbour]
                queue_g.append(new_path_g)
                visited_g.add(neighbour)

                if neighbour in visited_s:
                    for path in queue_s:
                        if path[-1] == neighbour:
                            return path + new_path_g[::-1][1:]

    return None


# ✅ Example Graph
graph = {
    'A': ['B', 'C'],
    'B': ['D', 'E'],
    'C': ['F'],
    'D': [],
    'E': ['G'],
    'F': [],
    'G': []
}

print(bidirectional_search(graph, 'A', 'G'))
# Out:
# None

# %%
# !pip install tensorflow

# %%
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize pixel values (0–255 → 0–1)
x_train = x_train / 255.0
x_test = x_test / 255.0

# One-hot encode labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Print shapes
print(x_train.shape, x_test.shape)
x_train_flatten = x_train.reshape(60000, 28*28)
x_test_flatten = x_test.reshape(10000, 28*28)
# ----- Step 2: Build the Model -----
model = Sequential([

    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')  # 10 outputs for digits 0–9
])

# ----- Step 3: Compile the Model -----
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# ----- Step 4: Train the Model -----
model.fit(x_train_flatten, y_train, epochs=5, batch_size=32, validation_split=0.1)
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# (60000, 28, 28) (10000, 28, 28)
# Epoch 1/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.8689 - loss: 0.4511 - val_accuracy: 0.9677 - val_loss: 0.1128
# Epoch 2/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.9664 - loss: 0.1135 - val_accuracy: 0.9708 - val_loss: 0.0921
# Epoch 3/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9757 - loss: 0.0759 - val_accuracy: 0.9758 - val_loss: 0.0835
# Epoch 4/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9821 - loss: 0.0573 - val_accuracy: 0.9777 - val_loss: 0.0739
# Epoch 5/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9865 - loss: 0.0439 - val_accuracy: 0.9763 - val_loss: 0.0773

# %%
import matplotlib.pyplot as plt
plt.imshow(x_train[0])

# %%
predictions=model.predict(x_test.reshape(10000, 28*28)[:5])
predicted_labels = predictions.argmax(axis=1)
print(predicted_labels)
loss,accuracy=model.evaluate(x_test_flatten,y_test)
print(accuracy*100)
print(loss*100)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# [7 2 1 0 4]
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9766 - loss: 0.0882
# 98.07000160217285
# 7.444240152835846

# %%
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# %%
class Node:
    def __init__(self, val, neighbors=[]):
        self.val = val
        self.neighbors = neighbors
        self.visited_right = False  # whether the node was reached by the BFS that started from source
        self.visited_left = False  # whether the node was reached by the BFS that started from destination
        self.parent_right = None  # used for retrieving the final path from source to the meeting point
        self.parent_left = None  # used for retrieving the final path from the meeting point to destination


# class Queue:
#    pass  # implement it yourself
from collections import deque

def bidirectional_search(s, t):
    def extract_path(node):
        """return the path when both BFS's have met"""
        node_copy = node
        path = []

        while node:
            path.append(node.val)
            node = node.parent_right

        path.reverse()
        del path[-1]  # because the meeting node appears twice

        while node_copy:
            path.append(node_copy.val)
            node_copy = node_copy.parent_left
        return path

    q = deque([])
    q.append(s)
    q.append(t)
    s.visited_right = True
    t.visited_left = True

    while len(q) > 0:
        n = q.pop()

        if n.visited_left and n.visited_right:  # if the node visited by both BFS's
            return extract_path(n)

        for node in n.neighbors:
            if n.visited_left == True and not node.visited_left:
                node.parent_left = n
                node.visited_left = True
                q.append(node)
            if n.visited_right == True and not node.visited_right:
                node.parent_right = n
                node.visited_right = True
                q.append(node)

    # not found
    return False


n0 = Node(0)
n1 = Node(1)
n2 = Node(2)
n3 = Node(3)
n4 = Node(4)
n5 = Node(5)
n6 = Node(6)
n7 = Node(7)
n0.neighbors = [n1, n5]
n1.neighbors = [n0, n2, n6]
n2.neighbors = [n1]
n3.neighbors = [n4, n6]
n4.neighbors = [n3]
n5.neighbors = [n0, n6]
n6.neighbors = [n1, n3, n5, n7]
n7.neighbors = [n6]
print(bidirectional_search(n0, n4))
# Out:
# [0, 5, 6, 3, 4]
